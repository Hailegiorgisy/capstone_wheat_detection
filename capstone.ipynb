# %%
import pandas as pandas 
import numpy as np 
import tensorflow as tf

# %%
pip install datasets
# Out:
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached hf_xet-1.2.0-cp37-abi3-win_amd64.whl.metadata (5.0 kB)
# ...
# Using cached hf_xet-1.2.0-cp37-abi3-win_amd64.whl (2.9 MB)
# ...
#    ---------------------------------------- 0.0/28.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/28.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/28.0 MB ? eta -:--:--
#     --------------------------------------- 0.5/28.0 MB 956.3 kB/s eta 0:00:29
#    - -------------------------------------- 0.8/28.0 MB 1.1 MB/s eta 0:00:24
#    - -------------------------------------- 1.0/28.0 MB 1.2 MB/s eta 0:00:22
#    - -------------------------------------- 1.3/28.0 MB 1.3 MB/s eta 0:00:21
#    -- ------------------------------------- 1.6/28.0 MB 1.2 MB/s eta 0:00:22
#    -- ------------------------------------- 2.1/28.0 MB 1.3 MB/s eta 0:00:20
#    --- ------------------------------------ 2.4/28.0 MB 1.3 MB/s eta 0:00:21
# ...

# %%
from datasets import load_dataset

ds = load_dataset("Etienne-David/GlobalWheatHeadDataset2021")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 from datasets import load_dataset
# ----> 3 ds = load_dataset("Etienne-David/GlobalWheatHeadDataset2021")
#
# File c:\Python313\Lib\site-packages\datasets\load.py:1512, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1509     return builder_instance.as_streaming_dataset(split=split)
#    1511 # Download and prepare data
# -> 1512 builder_instance.download_and_prepare(
#    1513     download_config=download_config,
#    1514     download_mode=download_mode,
#    1515     verification_mode=verification_mode,
#    1516     num_proc=num_proc,
#    1517     storage_options=storage_options,
#    1518 )
# ...
